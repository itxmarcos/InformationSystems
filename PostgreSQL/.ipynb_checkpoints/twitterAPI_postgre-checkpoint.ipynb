# %%
# Imports:
import tweepy
import psycopg2
import json

# %%
credentials = {}
credentials['api_key'] = 'n2dTtVbZuJwji0auruBGVTBwT'
credentials['api_secret_key'] = 'U1Er7hNUFtOwmPIz6BCr6w1B3o9GlKhg6loffJVIK0cFAFdkYl'
credentials['access_token'] = '987093510116532231-tiHjc16Ws3vcMZpNUt0kuL7xj8iLSy1'
credentials['access_token_secret'] = 'ykZmkTz2TIeSajyWDKXvSSxAiFZvMFdD9ePUe0zn5fsna'

# Load Twitter API keys
api_key = credentials['api_key']
api_secret_key = credentials['api_secret_key']
access_token = credentials['access_token']
access_token_secret = credentials['access_token_secret']

# Twitter initialization
auth = tweepy.OAuthHandler(api_key, api_secret_key)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
# Postgresql initialization
from configparser import ConfigParser
def config(filename='database.ini', section='postgresql'):
    # create a parser
    parser = ConfigParser()
    # read config file
    parser.read(filename)
    # get section, default to postgresql
    db = {}
    if parser.has_section(section):
        params = parser.items(section)
        for param in params:
            db[param[0]] = param[1]
    else:
        raise Exception('Section {0} not found in the {1} file'.format(section, filename))
    return db

def connect():
 """ Connect to the PostgreSQL database server """
 conn = None
 try:
     # read connection parameters
     params = config()
     # connect to the PostgreSQL server
     print('Connecting to the PostgreSQL database...')
     conn = psycopg2.connect(**params)
     # create a cursor
     cur = conn.cursor()

    # execute a statement
     print('PostgreSQL database version:')
     cur.execute('SELECT version()')
     # display the PostgreSQL database server version
     db_version = cur.fetchone()
     print(db_version)

     # close the communication with the PostgreSQL
     cur.close()
 except (Exception, psycopg2.DatabaseError) as error:
     print(error)
 finally:
     if conn is not None:
         conn.close()
     print('Database connection closed.')

# %%
def create_tables():
    """ create tables in the PostgreSQL database"""
    commands = (
        """
        DROP TABLE IF EXISTS users CASCADE;
        """,
        """
        CREATE TABLE users (
            user_id VARCHAR(30) PRIMARY KEY,
            user_name VARCHAR(30),
            followers_count VARCHAR(30),
            friends_count VARCHAR(30)
        );
        """,

        """
        DROP TABLE IF EXISTS tweets CASCADE;
        """,
        """
        CREATE TABLE tweets (
            tweet_id VARCHAR(30) PRIMARY KEY,
            user_id VARCHAR(30),
            FOREIGN KEY (user_id) REFERENCES users (user_id) ON DELETE CASCADE,
            created_at VARCHAR(30),
            text VARCHAR(300),
            favorite_count VARCHAR(300), 
            in_reply_to_screen_name VARCHAR(30),
            retweet_count VARCHAR(5),
            retweeted VARCHAR(5)
        );
        """
    )
    conn = None
    try:
        # read the connection parameters
        params = config()
        # connect to the PostgreSQL server
        conn = psycopg2.connect(**params)
        cur = conn.cursor()
        # create table one by one
        for command in commands:
            cur.execute(command)
        # close communication with the PostgreSQL database server
        cur.close()
        # commit the changes
        conn.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()

# %%
def insert_user(user_id, user_name, followers_count, friends_count):
    sql = """INSERT INTO users(user_id, user_name, followers_count, friends_count)
             VALUES(%s, %s, %s, %s) RETURNING user_id;"""
    conn = None
    id = None
    try:
        # read database configuration
        params = config()
        # connect to the PostgreSQL database
        conn = psycopg2.connect(**params)
        # create a new cursor
        cur = conn.cursor()
        # execute the INSERT statement
        cur.execute(sql, (user_id, user_name, followers_count, friends_count))
        # get the generated id back
        id = cur.fetchone()[0]
        # commit the changes to the database
        conn.commit()
        # close communication with the database
        cur.close()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
    return id

# %%
def insert_tweet(tweet_id, user_id, created_at, text, favorite_count, in_reply_to_screen_name, retweet_count, retweeted):
    sql = """INSERT INTO tweets(tweet_id, user_id, created_at, text, favorite_count, in_reply_to_screen_name, retweet_count, retweeted)
             VALUES(%s, %s, %s, %s, %s, %s, %s, %s) RETURNING tweet_id;"""
    conn = None
    id = None
    try:
        # read database configuration
        params = config()
        # connect to the PostgreSQL database
        conn = psycopg2.connect(**params)
        # create a new cursor
        cur = conn.cursor()
        # execute the INSERT statement
        cur.execute(sql, (tweet_id, user_id, created_at, text, favorite_count, in_reply_to_screen_name, retweet_count, retweeted))
        # get the generated id back
        id = cur.fetchone()[0]
        # commit the changes to the database
        conn.commit()
        # close communication with the database
        cur.close()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
 
    return id

# %%
# Helper function to get all tweets for a specified user
def get_all_tweets(screen_name):
    # initialize a list to hold all the tweepy Tweets
    alltweets = []
    
    # make initial request for most recent tweets (200 is the maximum allowed count)
    new_tweets = api.user_timeline(screen_name = screen_name,count=200)
    
    # save most recent tweets
    alltweets.extend(new_tweets)
    
    # save the id of the oldest tweet less one
    oldest = alltweets[-1].id - 1
    
    # keep grabbing tweets until there are no tweets left to grab
    while len(new_tweets) > 0:
        print("getting tweets before %s" % (oldest))
        
        # all subsiquent requests use the max_id param to prevent duplicates
        new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)
        
        # save most recent tweets
        alltweets.extend(new_tweets)
        
        # update the id of the oldest tweet less one
        oldest = alltweets[-1].id - 1
        
        print("...%s tweets downloaded so far" % (len(alltweets)))
            
    #write into postgres
    insert_user(alltweets[0].user.id_str, alltweets[0].user.screen_name, alltweets[0].user.followers_count, alltweets[0].user.friends_count)
    for tweet in alltweets:
        insert_tweet(tweet.id_str, tweet.user.id_str, tweet.created_at, tweet.text, tweet.favorite_count, tweet.in_reply_to_screen_name, tweet.retweet_count, tweet.retweeted)

# %%
def iter_row(cursor, size=10):
    while True:
        rows = cursor.fetchmany(size)
        if not rows:
            break
        for row in rows:
            yield row

# %%
def simple_query():
    """ get the tweets between two dates"""
    conn = None
    try:
        params = config()
        conn = psycopg2.connect(**params)
        cur = conn.cursor()
        cur.execute("""
            SELECT (tweets.created_at, tweets.text) FROM tweets WHERE CAST(created_at as date) BETWEEN '20200101' and '20200201'
        """)
        for row in iter_row(cur, 10):
            print(row)
        cur.close()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()

# %%
def join_query():
    """ get the users and tweets in which users have more than 40 followers and there are more than 5 retweets """
    conn = None
    try:
        params = config()
        conn = psycopg2.connect(**params)
        cur = conn.cursor()
        cur.execute("""
            SELECT (users.user_name, tweets.text) FROM tweets INNER JOIN users ON users.followers_count>=CAST(40 AS varchar(1)) AND tweets.retweet_count>=CAST(5 AS varchar(1))
        """)
        for row in iter_row(cur, 10):
            print(row)
        cur.close()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()

# %%
def aggregate_query():
    """ get the users ordered by followers """
    conn = None
    try:
        params = config()
        conn = psycopg2.connect(**params)
        cur = conn.cursor()
        cur.execute("""
            SELECT users.user_name, min(users.friends_count) FROM users GROUP BY users.user_name
        """)
        for row in iter_row(cur, 10):
            print(row)
        cur.close()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()

# %%
def search_query():
    """ get the tweets with the word iPhone """
    conn = None
    try:
        params = config()
        conn = psycopg2.connect(**params)
        cur = conn.cursor()
        cur.execute("""
            SELECT tweets.text FROM tweets WHERE tweets.text LIKE '%iPhone%'
        """)
        for row in iter_row(cur, 10):
            print(row)
        cur.close()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()

# %%
if __name__ == '__main__':
    connect()
    #create_tables()
    #get_all_tweets("srcaballero99") #pass in the username of the account you want to insert
    #get_all_tweets("Star_Lord987")
    #get_all_tweets("Rush2Loot")
    
    simple_query()
    join_query()
    aggregate_query()
    search_query()
# Out:
# Connecting to the PostgreSQL database...
# PostgreSQL database version:
# ('PostgreSQL 12.1 on x86_64-apple-darwin, compiled by Apple LLVM version 6.0 (clang-600.0.54) (based on LLVM 3.5svn), 64-bit',)
# Database connection closed.
# ('("2020-01-20 12:07:25","AI Career Pathways Report. Very helpful information.\nhttps://t.co/68wYyVoi0w")',)
# ('("2020-01-02 23:29:06","Google and NASA\'s Quantum Artificial Intelligence Lab https://t.co/A9pnNyeYXb")',)
# ('("2020-01-02 23:26:43",https://t.co/JjbWwKwEjf)',)
# ('("2020-01-02 19:13:05","Travelling Salesman Problem (https://t.co/nmpXKFDbwj) using Genetic Algorithm (https://t.co/groayMLOgQ) https://t.co/FS6OXcVe4j")',)
# ('("2020-02-01 00:16:48","Pensad que en este primer mes ha habido incendios gigantes, amenazas serias de guerra mundial, un virus que no para… https://t.co/1OjZ6QV52S")',)
# ('("2020-01-30 18:33:34","Hostia si es @adrizgz2 https://t.co/Dah6IAEI6O")',)
# ('("2020-01-29 14:40:41","RT @deltinonguema: https://t.co/ItTSEKpXCt")',)
# ('("2020-01-24 10:25:27","Bueno ahora ya en serio, el que este jugando a jumanji en Australia que pare, ya no es gracioso https://t.co/X4WZlzSIXP")',)
# ('("2020-01-23 16:47:51","Y encima para ver gilipolleces")',)
# ('("2020-01-23 16:47:09","Soy al unico que le pasa esto? ver en la tl comentarios y twits de cuentas que no siguo, que nadie de los que sigo… https://t.co/CxcY4YnsMW")',)
# ('("2020-01-22 16:49:56","https://t.co/1qBJgzHBda https://t.co/asg2HOHZ8h")',)
# ('("2020-01-21 12:47:57","Mis puntuaciones de personalidad de núcleo oscuro me hacen 31,89% más claro que la persona promedio. https://t.co/Fz9fgSZniw vía @idr_labs")',)
# ('("2020-01-20 19:17:45","La gente se asusta cuando les digo que estudio una ingeniería (9.6 de promedio), tengo novia, hablo fluidamente 4 i… https://t.co/TI5aGrJ8YO")',)
# ('(Rush2Loot,"RT @polarcapstudios: Two things that have monsters in them... #MonsterHunter: World, and our upcoming Actual Play DnD podcast Free Four All…")',)
# ('(Star_Lord987,"RT @TexmerYT: 🎉🏆SORTEO DE BANNER, HEADER, LOGO 🏆🎉 \nCOMPLETA LOS REQUISITOS Y MUCHA SUERTE 😜\nLINK: https://t.co/VUP9juVhDs https://t.co/9He9…")',)
# ('(Rush2Loot,"RT @TexmerYT: 🎉🏆SORTEO DE BANNER, HEADER, LOGO 🏆🎉 \nCOMPLETA LOS REQUISITOS Y MUCHA SUERTE 😜\nLINK: https://t.co/VUP9juVhDs https://t.co/9He9…")',)
# ('(Star_Lord987,"RT @MeroStation: ¡Sorteamos Kit Gaming de DeepTeam con teclado, ratón y mousepad!\n\nPara participar ➡️\n\n- Follow a @DeepGaming_ES y @MeroSta…")',)
# ('(Rush2Loot,"RT @MeroStation: ¡Sorteamos Kit Gaming de DeepTeam con teclado, ratón y mousepad!\n\nPara participar ➡️\n\n- Follow a @DeepGaming_ES y @MeroSta…")',)
# ('(Star_Lord987,"RT @polarcapstudios: RT &amp; Follow &amp; tell your friends family and dog about PolarCap for a chance to win a digital copy of #DBFZ for whatever…")',)
# ('(Rush2Loot,"RT @polarcapstudios: RT &amp; Follow &amp; tell your friends family and dog about PolarCap for a chance to win a digital copy of #DBFZ for whatever…")',)
# ('(Star_Lord987,"RT @MeroStation: ¡Sorteamos Funko Pop de Reaper #Overwatch!\n\nPara participar ➡️\n\n- Follow a @Frikimaestro y @MeroStation\n- RT a este tweet.…")',)
# ('(Rush2Loot,"RT @MeroStation: ¡Sorteamos Funko Pop de Reaper #Overwatch!\n\nPara participar ➡️\n\n- Follow a @Frikimaestro y @MeroStation\n- RT a este tweet.…")',)
# ('(Star_Lord987,"RT @SIitherinn: https://t.co/LSx8M9dqUS")',)
# ('(Rush2Loot,"RT @SIitherinn: https://t.co/LSx8M9dqUS")',)
# ('(Star_Lord987,"RT @MeroStation: ¡Sorteamos este pack que incluye: taza de Pokémon, alfombrilla de Cuphead y llavero de Super Mario!\n\nPara participar ➡️\n\n-…")',)
# ('(Rush2Loot,"RT @MeroStation: ¡Sorteamos este pack que incluye: taza de Pokémon, alfombrilla de Cuphead y llavero de Super Mario!\n\nPara participar ➡️\n\n-…")',)
# ('(Star_Lord987,"RT @C9Mang0: If this reaches 10k retweets \n\nIll bet 20k on the eagles winning the super bowl\n\n#Eagles")',)
# ('(Rush2Loot,"RT @C9Mang0: If this reaches 10k retweets \n\nIll bet 20k on the eagles winning the super bowl\n\n#Eagles")',)
# ('(Star_Lord987,"RT @xexu_fernandez: Has sido visitado por el perezoso aplicado de los estudios. Da RT para aprobar todos tus examenes de enero. https://t.c…")',)
# ('(Rush2Loot,"RT @xexu_fernandez: Has sido visitado por el perezoso aplicado de los estudios. Da RT para aprobar todos tus examenes de enero. https://t.c…")',)
# ('(Star_Lord987,"RT @Movistar_Riders: SORTEO | Ponemos 5 camisetas más de #MovistaryStarWars en juego. Participar es facilísimo. Así que ya sabéis. ¡A por e…")',)
# ('(Rush2Loot,"RT @Movistar_Riders: SORTEO | Ponemos 5 camisetas más de #MovistaryStarWars en juego. Participar es facilísimo. Así que ya sabéis. ¡A por e…")',)
# ('(Star_Lord987,"RT @IamCristinini: 🎁⚠️¡SORTEO!⚠️ 🎁\n\nFigura de Leona Oficial de @riotgames #LeagueOfLegends \n\nPara Participar:\n- RT al Tweet\n- Follow @IamCr…")',)
# ('(Rush2Loot,"RT @IamCristinini: 🎁⚠️¡SORTEO!⚠️ 🎁\n\nFigura de Leona Oficial de @riotgames #LeagueOfLegends \n\nPara Participar:\n- RT al Tweet\n- Follow @IamCr…")',)
# ('(Star_Lord987,"RT @Movistar_Riders: SORTEO | ¿Quién quiere la camiseta de #MovistaryStarWars? Conseguir una es muy fácil. Hay 5 en juego. Mirad. \n#LaFuerz…")',)
# ('(Rush2Loot,"RT @Movistar_Riders: SORTEO | ¿Quién quiere la camiseta de #MovistaryStarWars? Conseguir una es muy fácil. Hay 5 en juego. Mirad. \n#LaFuerz…")',)
# ('(Star_Lord987,"RT @Fade2Karma: #F2K and @VicTsing_ have partnered up for our biggest #giveaway yet! 500 PACKS/KEGS, F2K hoodie &amp; more! The contest ends on…")',)
# ('(Rush2Loot,"RT @Fade2Karma: #F2K and @VicTsing_ have partnered up for our biggest #giveaway yet! 500 PACKS/KEGS, F2K hoodie &amp; more! The contest ends on…")',)
# ('(Star_Lord987,"RT @Fade2Karma: Attention! In partnership with @MovieMaskTech we present you this blockbuster of a #giveaway, don\'t miss out on a chance to…")',)
# ('(Rush2Loot,"RT @Fade2Karma: Attention! In partnership with @MovieMaskTech we present you this blockbuster of a #giveaway, don\'t miss out on a chance to…")',)
# ('(Star_Lord987,"RT @AKA_Wonder: RT this tweet, follow @SKGaming , @MountainDew and @AKA_Wonder for the chance to win 5 Hearthstone packs! \n\nWinner in 30min…")',)
# ('(Rush2Loot,"RT @AKA_Wonder: RT this tweet, follow @SKGaming , @MountainDew and @AKA_Wonder for the chance to win 5 Hearthstone packs! \n\nWinner in 30min…")',)
# ('(Star_Lord987,"RT @JosPastr: Me muero. https://t.co/E0R1fmPURu")',)
# ('(Rush2Loot,"RT @JosPastr: Me muero. https://t.co/E0R1fmPURu")',)
# ('(Star_Lord987,"RT @LVPibai: La canción anti tilteo. Escucha esto cuando estés cabreado. El mejor vídeo de youtube https://t.co/kFDZqpWyAX")',)
# ('(Rush2Loot,"RT @LVPibai: La canción anti tilteo. Escucha esto cuando estés cabreado. El mejor vídeo de youtube https://t.co/kFDZqpWyAX")',)
# ('(Star_Lord987,"RT @ManuelBartual: Ando de vacaciones desde hace un par de días, en un hotel cerca de la playa. Iba todo bien hasta que han comenzado a suc…")',)
# ('(Rush2Loot,"RT @ManuelBartual: Ando de vacaciones desde hace un par de días, en un hotel cerca de la playa. Iba todo bien hasta que han comenzado a suc…")',)
# ('(Star_Lord987,"RT @Movistar_Riders: SORTEO | Prueba la beta de #CODWWII y conoce a los jugadores de #MovistarRiders. 10 pases dobles en juego. RT + Follow…")',)
# ('(Rush2Loot,"RT @Movistar_Riders: SORTEO | Prueba la beta de #CODWWII y conoce a los jugadores de #MovistarRiders. 10 pases dobles en juego. RT + Follow…")',)
# ('(Star_Lord987,"RT @Zetaeme_94: ¿Qué os parece este FREESTYLE RAPEANDO sobre @hearthstone_es en el streaming de ayer de @offerrall? ¿Queréis otro streaming…")',)
# ('(Rush2Loot,"RT @Zetaeme_94: ¿Qué os parece este FREESTYLE RAPEANDO sobre @hearthstone_es en el streaming de ayer de @offerrall? ¿Queréis otro streaming…")',)
# ('(Star_Lord987,"RT @TabernadelMana: ¿Puede competir con el mago esquelético? #Hearthstone #FrozenThrone\n\nRT \'Mago Sangriento Thalnos\'\nLIKE \'Fanática Contam…")',)
# ('(Rush2Loot,"RT @TabernadelMana: ¿Puede competir con el mago esquelético? #Hearthstone #FrozenThrone\n\nRT \'Mago Sangriento Thalnos\'\nLIKE \'Fanática Contam…")',)
# ('(Star_Lord987,"RT @RickandMorty: Guys. \nWe fucking did it.\nWE GOT THE SAUCE. https://t.co/1uPA8OtJCd")',)
# ('(Rush2Loot,"RT @RickandMorty: Guys. \nWe fucking did it.\nWE GOT THE SAUCE. https://t.co/1uPA8OtJCd")',)
# ('(Star_Lord987,"RT @Damkalloh: Remaquetando algunas de las cartas de Grim Doom, abro este hilo para enseñaroslas, va. \n\nCada 10RTs enseño una nueva!")',)
# ('(Rush2Loot,"RT @Damkalloh: Remaquetando algunas de las cartas de Grim Doom, abro este hilo para enseñaroslas, va. \n\nCada 10RTs enseño una nueva!")',)
# ('(Star_Lord987,"RT @SKGaming: FLASH GIVEAWAY @HyperX!\nRT this post and follow:\n@HyperX \n@SKGaming \n@AKA_Wonder \nfor your chance to win\n\nWinners announced i…")',)
# ('(Rush2Loot,"RT @SKGaming: FLASH GIVEAWAY @HyperX!\nRT this post and follow:\n@HyperX \n@SKGaming \n@AKA_Wonder \nfor your chance to win\n\nWinners announced i…")',)
# ('(Star_Lord987,"RT @FeelinkGamer: Va, 50 Retwits en 10 minutos y hago stream de Taberna Heroica.")',)
# ('(Rush2Loot,"RT @FeelinkGamer: Va, 50 Retwits en 10 minutos y hago stream de Taberna Heroica.")',)
# ('(Star_Lord987,"RT @yisucrist: ya tengo un nuevo idolo https://t.co/FP7RjpMTqa")',)
# ('(Rush2Loot,"RT @yisucrist: ya tengo un nuevo idolo https://t.co/FP7RjpMTqa")',)
# ('(Star_Lord987,"RT @Josemicod5: RT para participar en el sorteo de una de las tarjetas Battlenet :D ¡¡MUCHA SUERTE!! ✌ https://t.co/oJyZ9E1HjG")',)
# ('(Rush2Loot,"RT @Josemicod5: RT para participar en el sorteo de una de las tarjetas Battlenet :D ¡¡MUCHA SUERTE!! ✌ https://t.co/oJyZ9E1HjG")',)
# ('Rush2Loot', '4')
# ('Star_Lord987', '195')
# ('srcaballero99', '27')
# ('RT @BenGeskin: @LaughingQuoll Looks great on notchless iPhone 🔥\n\n(OnePlus 7 Pro) https://t.co/7H6ZU0MGwK',)
